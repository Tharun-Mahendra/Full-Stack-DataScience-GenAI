# %% [markdown]
# # Iris DataSet
# -     iris is an flower
# ![iris flower.png](attachment:a13983e5-0e1c-462c-b02e-d6fb45af202b.png)

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\TharunMahendra\OneDrive\Desktop\NIT\DataSets\iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
#lets drop ID as it is not useful
df.drop('Id',axis=1,inplace=True)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# -      There are no null values

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# -     Data has 3 types of Species

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(df.Species)

# %%
sns.countplot(data=df,x='Species',hue='Species')
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
sns.jointplot(data=df,x='SepalLengthCm',y='SepalWidthCm',kind='reg')

# %%
sns.jointplot(data=df,x='PetalLengthCm',y='PetalWidthCm',kind='reg')

# %%
sns.FacetGrid(df,hue='Species',height=5).map(plt.scatter,'SepalLengthCm','SepalWidthCm').add_legend()

# %%
sns.FacetGrid(df,hue='Species',height=5).map(plt.scatter,'PetalLengthCm','PetalWidthCm').add_legend()

# %%
sns.boxplot(df,x=df.Species,y=df.PetalLengthCm,hue='Species')
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
df.boxplot(by='Species',figsize=(12,8))
plt.show()

# %%
sns.stripplot(data=df,x=df.Species,y=df.SepalLengthCm,palette='winter',hue='SepalLengthCm')
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.boxplot(df,x=df.Species,y=df.SepalLengthCm,hue='Species')
sns.stripplot(data=df,x=df.Species,y=df.SepalLengthCm,palette='winter',hue='SepalLengthCm')
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.violinplot(data=df,x=df.Species,y=df.SepalLengthCm,color='m')
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.violinplot(data=df,x=df.Species,y=df.SepalLengthCm,color='m')
plt.subplot(2,2,2)
sns.violinplot(data=df,x=df.Species,y=df.PetalLengthCm,color='y')
plt.subplot(2,2,3)
sns.violinplot(data=df,x=df.Species,y=df.SepalWidthCm,color='g')
plt.subplot(2,2,4)
sns.violinplot(data=df,x=df.Species,y=df.PetalWidthCm,color='b')
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
sns.pairplot(data=df,kind='reg')

# %%
sns.pairplot(data=df,hue='Species')

# %%
data=df.copy()

# %%
data=data.drop('Species',axis=1)

# %%
sns.heatmap(data.corr(),cmap='cubehelix',linecolor='k',linewidths=2,square=True,mask=False,vmax=1,vmin=-1,annot=True,xticklabels=2)
# Out:
# <Axes: >

# %%
df.hist(edgecolor='black',figsize=(12,8),bins=20)
plt.show()

# %%
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings('ignore')

# %%
sns.swarmplot(data=df,x=df.Species,y=df.PetalLengthCm,hue='Species')
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.set_style('whitegrid')
sns.swarmplot(data=df,x=df.Species,y=df.PetalLengthCm,color='y',edgecolor='k',size=3)
sns.violinplot(data=df,x='Species',y='PetalLengthCm',color='m',inner=None)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.lmplot(data=df,x='PetalLengthCm',y='PetalWidthCm')

# %%
sns.FacetGrid(data=df,hue='Species',height=6).map(sns.kdeplot,'PetalLengthCm').add_legend()

# %%
sns.boxenplot(data=df,x='Species',y='SepalLengthCm',hue='Species')
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
plt.figure(figsize=(12,8))
plt.subplot(2,2,1)
sns.boxenplot(data=df,x=df.Species,y=df.SepalLengthCm,hue='Species')
plt.subplot(2,2,2)
sns.violinplot(data=df,x=df.Species,y=df.PetalLengthCm,color='y')
plt.subplot(2,2,3)
sns.boxplot(data=df,x=df.Species,y=df.SepalWidthCm,color='g')
plt.subplot(2,2,4)
sns.scatterplot(data=df,x=df.Species,y=df.PetalWidthCm,color='b')
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
iris_setosa=df[df['Species']=='Iris-setosa']
iris_setosa.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.kdeplot(data=iris_setosa[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])
# Out:
# <Axes: ylabel='Density'>
