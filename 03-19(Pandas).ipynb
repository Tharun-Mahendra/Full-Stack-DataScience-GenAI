# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
store=pd.read_csv(r"C:\Users\TharunMahendra\OneDrive\Desktop\NIT\Superstore_Orders.csv")

# %%
id(store) #adress of memeory allocation
# Out:
# 2510755011120

# %%
pd.set_option('display.max_colwidth',15) #max columnswidth to displayed set to 10 to display less matter 
pd.set_option('display.width',1)
(store)
# Out:
#              Category  \
# 0      Office Supp...
# 1      Office Supp...
# 2      Office Supp...
# 3      Office Supp...
# 4      Office Supp...
# ...               ...
# 10189  Office Supp...
# 10190  Office Supp...
# 10191  Office Supp...
# 10192      Technology
# 10193  Office Supp...
#
#                 City  \
# 0            Houston
# 1         Naperville
# 2         Naperville
# 3         Naperville
# 4       Philadelphia
# ...              ...
# 10189  New York City
# 10190      Fairfield
# 10191       Loveland
# 10192  New York City
# 10193  Charlottetown
#
#       Country/Region  \
# 0      United States
# 1      United States
# 2      United States
# 3      United States
# 4      United States
# ...              ...
# 10189  United States
# 10190  United States
# 10191  United States
# 10192  United States
# 10193         Canada
#
#         Customer Name  \
# 0       Darren Powers
# 1       Phillina Ober
# 2       Phillina Ober
# 3       Phillina Ober
# ...

# %%
len(store) #no.of rows
# Out:
# 10194

# %%
store.shape #rows,columns
# Out:
# (10194, 19)

# %%
store.columns #column names
# Out:
# Index(['Category',
#        'City',
#        'Country/Region',
#        'Customer Name',
#        'Manufacturer',
#        'Order Date',
#        'Order ID',
#        'Postal Code',
#        'Product Name',
#        'Region',
#        'Segment',
#        'Ship Date',
#        'Ship Mode',
#        'State/Province',
#        'Sub-Category',
#        'Discount',
#        'Profit',
#        'Quantity',
#        'Sales'],
#       dtype='object')

# %%
len(store.columns)
# Out:
# 19

# %%
store.isnull()
# Out:
#        Category  \
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 10189     False
# 10190     False
# 10191     False
# 10192     False
# 10193     False
#
#         City  \
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 10189  False
# 10190  False
# 10191  False
# 10192  False
# 10193  False
#
#        Country/Region  \
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 10189           False
# 10190           False
# 10191           False
# 10192           False
# 10193           False
#
#        Customer Name  \
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 10189          False
# 10190          False
# 10191          False
# 10192          False
# 10193          False
#
# ...

# %%
store.isnull().sum()
# Out:
# Category          0
# City              0
# Country/Region    0
# Customer Name     0
# Manufacturer      0
# Order Date        0
# Order ID          0
# Postal Code       0
# Product Name      0
# Region            0
# Segment           0
# Ship Date         0
# Ship Mode         0
# State/Province    0
# Sub-Category      0
# Discount          0
# Profit            0
# Quantity          0
# Sales             0
# dtype: int64

# %%
store[:]
# Out:
#              Category  \
# 0      Office Supp...
# 1      Office Supp...
# 2      Office Supp...
# 3      Office Supp...
# 4      Office Supp...
# ...               ...
# 10189  Office Supp...
# 10190  Office Supp...
# 10191  Office Supp...
# 10192      Technology
# 10193  Office Supp...
#
#                 City  \
# 0            Houston
# 1         Naperville
# 2         Naperville
# 3         Naperville
# 4       Philadelphia
# ...              ...
# 10189  New York City
# 10190      Fairfield
# 10191       Loveland
# 10192  New York City
# 10193  Charlottetown
#
#       Country/Region  \
# 0      United States
# 1      United States
# 2      United States
# 3      United States
# 4      United States
# ...              ...
# 10189  United States
# 10190  United States
# 10191  United States
# 10192  United States
# 10193         Canada
#
#         Customer Name  \
# 0       Darren Powers
# 1       Phillina Ober
# 2       Phillina Ober
# 3       Phillina Ober
# ...

# %%
store[0:10]
# Out:
#          Category  \
# 0  Office Supp...
# 1  Office Supp...
# 2  Office Supp...
# 3  Office Supp...
# 4  Office Supp...
# 5       Furniture
# 6  Office Supp...
# 7  Office Supp...
# 8  Office Supp...
# 9  Office Supp...
#
#            City  \
# 0       Houston
# 1    Naperville
# 2    Naperville
# 3    Naperville
# 4  Philadelphia
# 5     Henderson
# 6     Henderson
# 7        Athens
# 8     Henderson
# 9     Henderson
#
#   Country/Region  \
# 0  United States
# 1  United States
# 2  United States
# 3  United States
# 4  United States
# 5  United States
# 6  United States
# 7  United States
# 8  United States
# 9  United States
#
#    Customer Name  \
# 0  Darren Powers
# 1  Phillina Ober
# 2  Phillina Ober
# 3  Phillina Ober
# 4     Mick Brown
# 5  Maria Etezadi
# 6  Maria Etezadi
# 7  Jack O'Briant
# 8  Maria Etezadi
# 9  Maria Etezadi
#
#    Manufacturer  \
# 0  Message Book
# 1           GBC
# 2         Avery
# 3         SAFCO
# 4         Avery
# 5        Global
# ...

# %%
store[0:20:5]
# Out:
#           Category  \
# 0   Office Supp...
# 5        Furniture
# 10  Office Supp...
# 15  Office Supp...
#
#           City  \
# 0      Houston
# 5    Henderson
# 10   Henderson
# 15  Huntsville
#
#    Country/Region  \
# 0   United States
# 5   United States
# 10  United States
# 15  United States
#
#      Customer Name  \
# 0    Darren Powers
# 5    Maria Etezadi
# 10   Maria Etezadi
# 15  Vivek Sunda...
#
#     Manufacturer  \
# 0   Message Book
# 5         Global
# 10    Southworth
# 15          Acco
#
#     Order Date  \
# 0   03-01-2020
# 5   06-01-2020
# 10  06-01-2020
# 15  07-01-2020
#
#           Order ID  \
# 0   US-2020-103800
# 5   US-2020-167199
# 10  US-2020-167199
# 15  US-2020-105417
#
#    Postal Code  \
# 0        77015
# 5        42420
# 10       42420
# 15       77340
#
#       Product Name  \
# 0   Message Boo...
# 5   Global Delu...
# 10  Southworth ...
# 15  Acco Four P...
#
#      Region  \
# 0   Central
# 5     South
# 10    South
# 15  Central
#
# ...

# %%
store.head() #top 5 rows
# Out:
#          Category  \
# 0  Office Supp...
# 1  Office Supp...
# 2  Office Supp...
# 3  Office Supp...
# 4  Office Supp...
#
#            City  \
# 0       Houston
# 1    Naperville
# 2    Naperville
# 3    Naperville
# 4  Philadelphia
#
#   Country/Region  \
# 0  United States
# 1  United States
# 2  United States
# 3  United States
# 4  United States
#
#    Customer Name  \
# 0  Darren Powers
# 1  Phillina Ober
# 2  Phillina Ober
# 3  Phillina Ober
# 4     Mick Brown
#
#    Manufacturer  \
# 0  Message Book
# 1           GBC
# 2         Avery
# 3         SAFCO
# 4         Avery
#
#    Order Date  \
# 0  03-01-2020
# 1  04-01-2020
# 2  04-01-2020
# 3  04-01-2020
# 4  05-01-2020
#
#          Order ID  \
# 0  US-2020-103800
# 1  US-2020-112326
# 2  US-2020-112326
# 3  US-2020-112326
# 4  US-2020-141817
#
#   Postal Code  \
# 0       77015
# 1       60540
# 2       60540
# 3       60540
# 4       19143
#
#      Product Name  \
# 0  Message Boo...
# 1  GBC Standar...
# 2       Avery 508
# ...

# %%
store.head(3) #top 3
# Out:
#          Category  \
# 0  Office Supp...
# 1  Office Supp...
# 2  Office Supp...
#
#          City  \
# 0     Houston
# 1  Naperville
# 2  Naperville
#
#   Country/Region  \
# 0  United States
# 1  United States
# 2  United States
#
#    Customer Name  \
# 0  Darren Powers
# 1  Phillina Ober
# 2  Phillina Ober
#
#    Manufacturer  \
# 0  Message Book
# 1           GBC
# 2         Avery
#
#    Order Date  \
# 0  03-01-2020
# 1  04-01-2020
# 2  04-01-2020
#
#          Order ID  \
# 0  US-2020-103800
# 1  US-2020-112326
# 2  US-2020-112326
#
#   Postal Code  \
# 0       77015
# 1       60540
# 2       60540
#
#      Product Name  \
# 0  Message Boo...
# 1  GBC Standar...
# 2       Avery 508
#
#     Region  \
# 0  Central
# 1  Central
# 2  Central
#
#        Segment  \
# 0     Consumer
# 1  Home Office
# 2  Home Office
#
#     Ship Date  \
# 0  07-01-2020
# 1  08-01-2020
# 2  08-01-2020
#
#         Ship Mode  \
# 0  Standard Class
# 1  Standard Class
# 2  Standard Class
#
# ...

# %%
store.tail() # bottom 5 rows
# Out:
#              Category  \
# 10189  Office Supp...
# 10190  Office Supp...
# 10191  Office Supp...
# 10192      Technology
# 10193  Office Supp...
#
#                 City  \
# 10189  New York City
# 10190      Fairfield
# 10191       Loveland
# 10192  New York City
# 10193  Charlottetown
#
#       Country/Region  \
# 10189  United States
# 10190  United States
# 10191  United States
# 10192  United States
# 10193         Canada
#
#         Customer Name  \
# 10189  Patrick O'D...
# 10190      Erica Bern
# 10191   Jill Matthias
# 10192  Patrick O'D...
# 10193     Harry Olson
#
#        Manufacturer  \
# 10189  Wilson Jones
# 10190           GBC
# 10191         Other
# 10192         Other
# 10193  Wilson Jones
#
#        Order Date  \
# 10189  30-12-2023
# 10190  30-12-2023
# 10191  30-12-2023
# 10192  30-12-2023
# 10193  30-12-2023
#
#              Order ID  \
# 10189  US-2023-143259
# 10190  US-2023-115427
# 10191  US-2023-156720
# 10192  US-2023-143259
# 10193  CA-2023-143500
#
# ...

# %%
store.tail(3) #bottom 3
# Out:
#              Category  \
# 10191  Office Supp...
# 10192      Technology
# 10193  Office Supp...
#
#                 City  \
# 10191       Loveland
# 10192  New York City
# 10193  Charlottetown
#
#       Country/Region  \
# 10191  United States
# 10192  United States
# 10193         Canada
#
#         Customer Name  \
# 10191   Jill Matthias
# 10192  Patrick O'D...
# 10193     Harry Olson
#
#        Manufacturer  \
# 10191         Other
# 10192         Other
# 10193  Wilson Jones
#
#        Order Date  \
# 10191  30-12-2023
# 10192  30-12-2023
# 10193  30-12-2023
#
#              Order ID  \
# 10191  US-2023-156720
# 10192  US-2023-143259
# 10193  CA-2023-143500
#
#       Postal Code  \
# 10191       80538
# 10192       10009
# 10193         C0A
#
#          Product Name  \
# 10191  Bagged Rubb...
# 10192  Gear Head A...
# 10193  Wilson Jone...
#
#       Region  \
# 10191   West
# 10192   East
# 10193   East
#
#         Segment  \
# 10191  Consumer
# 10192  Consumer
# ...
