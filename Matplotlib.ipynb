# %% [markdown]
# # Matplotlib
# - Matplotlib is a powerful library in Python used for creating static, interactive, and animated visualizations. It's widely utilized for plotting data and is compatible with other popular Python libraries such as NumPy and Pandas.
# - With Matplotlib, we can produce a variety of plots, including line charts, scatter plots, bar charts, histograms, and more, all with customizable features to make our data presentation visually engaging.
# - When we want to convey some information to others, there are several ways to do so. The process of conveying the information with the help of plots and graphics is called **Data Visualization**. The plots and graphics take numerical data as input and display output in the form of charts, figures and tables. It helps to analyze and visualize the data clearly and make concrete decisions. It makes complex data more accessible and understandable. The goal of data visualization is to communicate information in a clear and efficient manner.

# %% [markdown]
#  `Lets Import Libraries`

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Displaying Plots
# ##### Plotting From a Script
# - If we are using Matplotlib from within a script, then the `plt.show()` command is of great use. It starts an event loop, looks for all currently active figure objects, and opens one or more interactive windows that display the figure or figures. The plt.show() command should be used only once per Python session. It should be used only at the end of the script. Multiple plt.show() commands can lead to unpredictable results and should mostly be avoided.
# ##### Plotting From an IPython-Shell
# - We can use Matplotlib interactively within an IPython shell. IPython works well with Matplotlib if we specify Matplotlib mode. To enable this mode, we can use the `%matplotlib` magic command after starting ipython. Any plt plot command will cause a figure window to open and further commands can be run to update the plot.
# ##### Plotting From a Jupyter-Notebook
# - `%matplotlib notebook` – This command will produce interactive plots embedded within the notebook.
# - `%matplotlib inline` – It will output static images of the plot embedded in the notebook.

# %%
data=np.linspace(0,10,50)
data
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
plt.plot(data,'*:')

# %%
plt.plot(data,np.sin(data),'-.')
plt.plot(data,np.cos(data),':')

# %% [markdown]
# ### Matplotlib API
# -     Matplotlib provides a robust API for creating visualizations in Python. Here’s an overview:
# - `Pyplot Interface`: A simple, MATLAB-like interface for creating plots. Functions like `plt.plot()` `plt.scatter()` and `plt.bar()` are part of this interface.
# - `Object-Oriented Interface`: Offers more control and flexibility. We directly work with objects like Figure, Axes, Line2D, and others.

# %% [markdown]
# ### Pyplot API
# -     The Pyplot API is a user-friendly interface in Matplotlib that allows us to create visualizations quickly and easily, resembling MATLAB-style plotting. Here's an overview:
# #### Key Features of Pyplot API:
# ##### Simple Plotting Functions:
# - `plt.plot()`: For line plots.
# - `plt.scatter()`: For scatter plots.
# - `plt.bar()`: For bar charts.
# - `plt.hist()`: For histograms.
# ##### Customizations:
# - Add labels: `plt.xlabel()` `plt.ylabel()` `plt.title()`.
# - Modify axis ranges: `plt.xlim()` and `plt.ylim()`.
# ##### Annotations and Decorations:
# - Add legends: `plt.legend()`.
# - Gridlines: `plt.grid()`.
# ##### Showing and Saving:
# - Display plots: `plt.show()`.
# - Save plots to files: `plt.savefig`('filename.png').
# ##### We can get a reference to the current figure and axes using the following commands-
# - `plt.gcf()` # get current figure
# - `plt.gca()` # get current axes

# %%
plt.subplot(2,1,1) #Add an Axes to the current figure or retrieve an existing Axes.
plt.plot(data,np.cos(data),'--')

# %%
plt.subplot(2,1,1) #rows,columns,panelnumber
plt.plot(data,np.cos(data),'*')
plt.subplot(2,1,2)
plt.plot(data,np.sin(data),'--')

# %%
plt.gcf()

# %%
plt.gca()
# Out:
# <Axes: >

# %% [markdown]
# ### Visualization Using Pyplot

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]

plt.plot(x, y, color='k', marker='o', linestyle='--', label='Line Data')

plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Visualization Example')
plt.legend()
plt.grid(True)
plt.show()

# %%
data=np.linspace(0,2,100)

# %%
data
# Out:
# array([0.        , 0.02020202, 0.04040404, 0.06060606, 0.08080808,
#        0.1010101 , 0.12121212, 0.14141414, 0.16161616, 0.18181818,
#        0.2020202 , 0.22222222, 0.24242424, 0.26262626, 0.28282828,
#        0.3030303 , 0.32323232, 0.34343434, 0.36363636, 0.38383838,
#        0.4040404 , 0.42424242, 0.44444444, 0.46464646, 0.48484848,
#        0.50505051, 0.52525253, 0.54545455, 0.56565657, 0.58585859,
#        0.60606061, 0.62626263, 0.64646465, 0.66666667, 0.68686869,
#        0.70707071, 0.72727273, 0.74747475, 0.76767677, 0.78787879,
#        0.80808081, 0.82828283, 0.84848485, 0.86868687, 0.88888889,
#        0.90909091, 0.92929293, 0.94949495, 0.96969697, 0.98989899,
#        1.01010101, 1.03030303, 1.05050505, 1.07070707, 1.09090909,
#        1.11111111, 1.13131313, 1.15151515, 1.17171717, 1.19191919,
#        1.21212121, 1.23232323, 1.25252525, 1.27272727, 1.29292929,
#        1.31313131, 1.33333333, 1.35353535, 1.37373737, 1.39393939,
# ...

# %%
plt.plot(data,data**1,label='LinearData')
plt.plot(data,data**2,label='QuadraticData')
plt.plot(data,data**3,label='CubicData')
plt.legend()

plt.xlabel('Data')
plt.ylabel('Equation')
plt.title("DataManipulation")
# Out:
# Text(0.5, 1.0, 'DataManipulation')

# %%
data=np.arange(0.,5.,0.2)
plt.plot(data,data,'r*',   data,data**2,'ks',   data,data**3,'b^')

# %% [markdown]
# ### Object-Oriented API
# -     The Object-Oriented API in Matplotlib allows us to create and customize visualizations by working directly with its objects, such as Figure and Axes. It offers more control and flexibility compared to the Pyplot API.
# #### Key Components of the Object-Oriented API:
# ##### Figure:
# - The top-level container for all plot elements. It represents the entire visualization or canvas.
# ##### Axes:
# - A region within a Figure where the data is plotted. It includes the x and y axes.
# ##### Axis:
# - Handles properties of the x-axis and y-axis.
# ##### Methods:
# - `Axes.plot()`: To create line plots.
# - `Axes.set_title()` `Axes.set_xlabel()` `Axes.set_ylabel()` for labels.

# %%
fig,ax=plt.subplots(2)
data=np.linspace(0,10,50)
ax[0].plot(data,np.sin(data),'b:')
ax[1].plot(data,np.cos(data),'b--')

# %% [markdown]
# ### Objects and Reference
# -     The main idea with the Object Oriented API is to have objects that one can apply functions and actions on. The real advantage of this approach becomes apparent when more than one figure is created or when a figure contains more than one subplot.

# %%
fig=plt.figure()
x=np.linspace(0, 5, 10)
y=x**2
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x, y,'r')

# %% [markdown]
# ### Figure and Axes
# -     I start by creating a figure and an axes. A figure and axes can be created as follows:
# - `fig = plt.figure()`
# - `ax = plt.axes()`
# - In Matplotlib, the figure (an instance of the class `plt.figure`) is a single container that contains all the objects representing axes, graphics, text and labels. The axes (an instance of the class `plt.axes`) is a bounding box with ticks and labels. It will contain the plot elements that make up the visualization. I have used the variable name fig to refer to a figure instance, and ax to refer to an axes instance or group of axes instances.

# %%
fig=plt.figure()

# %%
ax=plt.axes()

# %% [markdown]
# ### Figure and Subplots
# -     Plots in Matplotlib reside within a Figure object. As described earlier, we can create a new figure with plt.figure()
# - `fig = plt.figure()`
# - Now, I create one or more subplots using fig.add_subplot() as follows:-
# - `ax1 = fig.add_subplot(2, 2, 1)`
# - The above command means that there are four plots in total (2*2 = 4). I select the first of four subplots (numbered from 1).
# - I create the next three subplots using the fig.add_subplot() commands as follows:-
# - `ax2 = fig.add_subplot(2, 2, 2)`
# - `ax3 = fig.add_subplot(2, 2, 3)`
# - `ax4 = fig.add_subplot(2, 2, 4)`

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

# %% [markdown]
# ### Parts Of Plot
# ![Anatomy_1.png](attachment:a6fce417-0111-42ff-b6fd-430189d83a47.png)

# %% [markdown]
# ### Saving the Plot
# -     We can save the figures in a wide variety of formats. We can save them using the **savefig()** command as follows:-
# - `fig.savefig(‘fig1.png’)`
# - We can explore the contents of the file using the IPython **Image** object.
# - `from IPython.display import Image`
# - `Image(‘fig1.png’)`
# - In **savefig()** command, the file format is inferred from the extension of the given filename. Depending on the backend,
# many different file formats are available. The list of supported file types can be found by using the get_supported_filetypes() method of the figure canvas object as follows:-
# - `fig.canvas.get_supported_filetypes()`

# %%
fig.savefig('plot.png') #lastfigure

# %%
from IPython.display import Image
Image('plot.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# ### Line-Plot

# %%
data=np.linspace(0,10,1000)
plt.plot(data,np.sin(data),'b-')

# %% [markdown]
# ### Scatter-Plot

# %%
data=np.linspace(0,10,50)
plt.plot(data,np.sin(data),'ko')

# %% [markdown]
# ### Histogram

# %%
data=np.random.rand(100)
plt.hist(data)
# Out:
# (array([13., 10., 12.,  9., 10., 13.,  9.,  9.,  7.,  8.]),
#  array([0.01432615, 0.11263   , 0.21093386, 0.30923771, 0.40754156,
#         0.50584542, 0.60414927, 0.70245312, 0.80075697, 0.89906083,
#         0.99736468]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Bar-Plot

# %%
#vertical
data=[5,10,15,20,25,20,15,10,5]
plt.bar(range(len(data)),data)
# Out:
# <BarContainer object of 9 artists>

# %%
#horizontal
plt.barh(range(len(data)),data)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### Error-BarChart
# - In experimental design, the measurements lack perfect precision. So, we have to repeat the measurements. It results in obtaining a set of values. The representation of the distribution of data values is done by plotting a single data point (known as mean value of dataset) and an error bar to represent the overall distribution of data.
# - We can use Matplotlib's errorbar() function to represent the distribution of data values. It can be done as follows:-

# %%
data=np.arange(0,4,0.2)
data
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8])

# %%
exp=np.exp(-data)
exp
# Out:
# array([1.        , 0.81873075, 0.67032005, 0.54881164, 0.44932896,
#        0.36787944, 0.30119421, 0.24659696, 0.20189652, 0.16529889,
#        0.13533528, 0.11080316, 0.09071795, 0.07427358, 0.06081006,
#        0.04978707, 0.0407622 , 0.03337327, 0.02732372, 0.02237077])

# %%
e1 = 0.1 * np.abs(np.random.randn(len(exp)))
e1
# Out:
# array([0.0736581 , 0.10595911, 0.07174495, 0.07658042, 0.01788706,
#        0.14513445, 0.03604514, 0.05378745, 0.09246898, 0.02390266,
#        0.0143609 , 0.12957594, 0.0126599 , 0.04256972, 0.20449742,
#        0.09516337, 0.07277755, 0.20069789, 0.0800995 , 0.01742718])

# %%
plt.errorbar(data,exp,yerr=e1,fmt='.-')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# #### Stacked-BarChart
# - We can draw stacked bar chart by using a special parameter called `bottom` from the `plt.bar()` function.

# %%
a=[10,15,25,8,16]
b=[25,14,8,5,14]
bars=range(5)

# %%
plt.bar(bars,a,color='r')
plt.bar(bars,b,color='b',bottom=a) #bottom specifies starting position of bar where a ends start b there
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### PieChart

# %%
data=[25,15,35,48,55]
names=['25%data','15%data','35%data','48%data','55%data']
plt.pie(data,labels=names)
plt.show()

# %% [markdown]
# ### Box-Plot
# -     Boxplot allows us to compare distributions of values by showing the median, quartiles, maximum and minimum of a set of values.

# %%
data=[19,52,83,25,47,38],[25,48,18,31,65,19,]

# %%
plt.boxplot(data)
plt.show()

# %% [markdown]
# ### Area Chart
# - An Area Chart is very similar to a `Line Chart`. The area between the x-axis and the line is filled in with color or shading. It represents the evolution of a numerical variable following another numerical variable.

# %%
x=range(0,5)
y=np.random.randint(0,10,5)
plt.fill_between(x,y) #or plt.stackplot(x,y)

# %% [markdown]
# ### Contour-Plots
# - Contour plots are a graphical representation used to show the values of a function across two dimensions. They depict curves where the function maintains a constant value, and the `contours` give a visual sense of how the function behaves whether it's increasing, decreasing, or staying steady.

# %%
data=np.random.rand(5,10)
data
# Out:
# array([[0.80533204, 0.59867702, 0.5687808 , 0.34661432, 0.68443064,
#         0.0532839 , 0.24585782, 0.61895144, 0.25816852, 0.5999271 ],
#        [0.7406609 , 0.84228772, 0.88498975, 0.96471711, 0.74858009,
#         0.78466314, 0.09329797, 0.68270572, 0.10889858, 0.68171217],
#        [0.03543617, 0.78461752, 0.03923478, 0.45387672, 0.07664769,
#         0.07444836, 0.06331471, 0.54181404, 0.37481119, 0.97058821],
#        [0.7606158 , 0.42120998, 0.42632659, 0.14297918, 0.12827876,
#         0.5642644 , 0.79945117, 0.47258486, 0.54803222, 0.57710304],
#        [0.08301384, 0.52163002, 0.90546195, 0.04346505, 0.64694614,
#         0.32418661, 0.44883993, 0.88582693, 0.49529496, 0.99565924]])

# %%
plt.contour(data)

# %% [markdown]
# ### Handling Axes

# %%
data=np.arange(1,5)
plt.plot(data,data*1,'m',   data,data*2,'y',   data,data*3,'b')
plt.axis()
# Out:
# (0.85, 4.15, 0.44999999999999996, 12.55)

# %%
plt.plot(data,data*1,'m',   data,data*2,'y',   data,data*3,'b')
plt.axis([0,5,0,12])
# Out:
# (0.0, 5.0, 0.0, 12.0)

# %%
plt.plot(data,data*1,'m',   data,data*2,'y',   data,data*3,'b')
plt.xticks([2,6,10])
plt.yticks([0,10])
# Out:
# ([<matplotlib.axis.YTick at 0x28309ae5eb0>,
# ...
#  [Text(0, 0, '0'), Text(0, 10, '10')])

# %% [markdown]
# ### Adding Labels,Title,legend,Grid

# %%
plt.plot(data,data*1,'m--^',   data,data*2,'y:o',   data,data*3,'b*:')
plt.xlabel('data')
plt.ylabel('multiples of data')
plt.title('DataManipulation')
plt.legend(['*1','*2','*3'])
plt.grid(True)
