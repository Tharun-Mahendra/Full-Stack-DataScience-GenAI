# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\TharunMahendra\OneDrive\Desktop\NIT\DataSets\Country_GDP_data.csv")

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
len(df)
# Out:
# 195

# %%
df.shape
# Out:
# (195, 5)

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df.columns)
# Out:
# 5

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %% [markdown]
# #### Transpose()

# %%
df.describe().transpose()
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %%
df.describe().T
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %% [markdown]
# #### changing column names

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.columns=['a','b','c','d','e']

# %%
df.head(1)
# Out:
#        a    b       c     d            e
# 0  Aruba  ABW  10.244  78.9  High income

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df.columns=['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup']

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df.dtypes
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# dtype: object

# %% [markdown]
# ## Slicing on dataframe

# %% [markdown]
# #### rows

# %%
df[:] #all rows
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df[0:10] #top 10 rows
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
df[10:] #10 to lasttt
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 10         Azerbaijan         AZE     18.300        58.7000
# 11            Burundi         BDI     44.151         1.3000
# 12            Belgium         BEL     11.200        82.1702
# 13              Benin         BEN     36.440         4.9000
# 14       Burkina Faso         BFA     40.551         9.1000
# ..                ...         ...        ...            ...
# 190       Yemen, Rep.         YEM     32.947        20.0000
# 191      South Africa         ZAF     20.850        46.5000
# 192  Congo, Dem. Rep.         COD     42.394         2.2000
# 193            Zambia         ZMB     40.471        15.4000
# 194          Zimbabwe         ZWE     35.715        18.5000
#
#              IncomeGroup
# 10   Upper middle income
# 11            Low income
# 12           High income
# 13            Low income
# 14            Low income
# ..                   ...
# 190  Lower middle income
# 191  Upper middle income
# ...

# %%
df[::50] #every 50th row
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244      78.900000          High income
# 50      Ecuador         ECU     21.070      40.353684  Upper middle income
# 100       Libya         LBY     21.425      16.500000  Upper middle income
# 150       Sudan         SDN     33.477      22.700000  Lower middle income

# %%
df[::-1] #reverse
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %% [markdown]
# #### columns

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
df[['CountryName','CountryCode']]
# Out:
#               CountryName CountryCode
# 0                   Aruba         ABW
# 1             Afghanistan         AFG
# 2                  Angola         AGO
# 3                 Albania         ALB
# 4    United Arab Emirates         ARE
# ..                    ...         ...
# 190           Yemen, Rep.         YEM
# 191          South Africa         ZAF
# 192      Congo, Dem. Rep.         COD
# 193                Zambia         ZMB
# 194              Zimbabwe         ZWE
#
# [195 rows x 2 columns]

# %%
df[['CountryName','CountryCode','IncomeGroup']]
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %% [markdown]
# #### lets combine both

# %%
df[::25][['CountryName','InternetUsers']] #every 25th row;both columns
# Out:
#     CountryName  InternetUsers
# 0         Aruba      78.900000
# 25     Barbados      73.000000
# 50      Ecuador      40.353684
# 75     Honduras      17.800000
# 100       Libya      16.500000
# 125     Namibia      13.900000
# 150       Sudan      22.700000
# 175     Tunisia      43.800000

# %%
df[::50][['BirthRate','IncomeGroup']]
# Out:
#      BirthRate          IncomeGroup
# 0       10.244          High income
# 50      21.070  Upper middle income
# 100     21.425  Upper middle income
# 150     33.477  Lower middle income

# %% [markdown]
# ## Mathametical Operations

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
print(df['CountryName']+"====="+df['IncomeGroup']) #we can add two object type data but we cant concatenate
# Out:
# 0                     Aruba=====High income
# 1                Afghanistan=====Low income
# 2            Angola=====Upper middle income
# 3           Albania=====Upper middle income
# 4      United Arab Emirates=====High income
#                        ...
# 190     Yemen, Rep.=====Lower middle income
# 191    South Africa=====Upper middle income
# 192         Congo, Dem. Rep.=====Low income
# 193          Zambia=====Lower middle income
# 194                 Zimbabwe=====Low income
# Length: 195, dtype: object

# %%
df['BirthRate']*df['InternetUsers']
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
df['BirthRate']+df['InternetUsers']
# Out:
# 0      89.144
# 1      41.153
# 2      65.085
# 3      70.077
# 4      99.044
#         ...
# 190    52.947
# 191    67.350
# 192    44.594
# 193    55.871
# 194    54.215
# Length: 195, dtype: float64

# %% [markdown]
# ## Modifying data

# %% [markdown]
# #### adding column

# %%
 df['newcol']=df['BirthRate']*df['InternetUsers']

# %%
df[0:2]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup    newcol
# 0        Aruba         ABW     10.244           78.9  High income  808.2516
# 1  Afghanistan         AFG     35.253            5.9   Low income  207.9927

# %% [markdown]
# #### removing column

# %%
df.drop('newcol',axis=1) #axis=1 indicates column
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup    newcol
# 0        Aruba         ABW     10.244           78.9  High income  808.2516
# 1  Afghanistan         AFG     35.253            5.9   Low income  207.9927

# %%
df=df.drop('newcol',axis=1) # to remove permanently

# %%
df.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df.BirthRate
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: BirthRate, Length: 195, dtype: float64

# %%
df.BirthRate<15 #lessthan
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: BirthRate, Length: 195, dtype: bool

# %%
filter=df.BirthRate>15

# %%
filter
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 190     True
# 191     True
# 192     True
# 193     True
# 194     True
# Name: BirthRate, Length: 195, dtype: bool

# %%
df[filter].count() #70 true rows
# Out:
# CountryName      124
# CountryCode      124
# BirthRate        124
# InternetUsers    124
# IncomeGroup      124
# dtype: int64

# %%
df[filter] #it prints the fitered values
# Out:
#              CountryName CountryCode  BirthRate  InternetUsers  \
# 1            Afghanistan         AFG     35.253            5.9
# 2                 Angola         AGO     45.985           19.1
# 5              Argentina         ARG     17.716           59.9
# 7    Antigua and Barbuda         ATG     16.447           63.4
# 10            Azerbaijan         AZE     18.300           58.7
# ..                   ...         ...        ...            ...
# 190          Yemen, Rep.         YEM     32.947           20.0
# 191         South Africa         ZAF     20.850           46.5
# 192     Congo, Dem. Rep.         COD     42.394            2.2
# 193               Zambia         ZMB     40.471           15.4
# 194             Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 1             Low income
# 2    Upper middle income
# 5            High income
# 7            High income
# 10   Upper middle income
# ..                   ...
# ...

# %%
filter2=df['BirthRate']<100

# %%
filter2
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 190    True
# 191    True
# 192    True
# 193    True
# 194    True
# Name: BirthRate, Length: 195, dtype: bool

# %%
df[filter&filter2] #greater than 15 less than 100
# Out:
#              CountryName CountryCode  BirthRate  InternetUsers  \
# 1            Afghanistan         AFG     35.253            5.9
# 2                 Angola         AGO     45.985           19.1
# 5              Argentina         ARG     17.716           59.9
# 7    Antigua and Barbuda         ATG     16.447           63.4
# 10            Azerbaijan         AZE     18.300           58.7
# ..                   ...         ...        ...            ...
# 190          Yemen, Rep.         YEM     32.947           20.0
# 191         South Africa         ZAF     20.850           46.5
# 192     Congo, Dem. Rep.         COD     42.394            2.2
# 193               Zambia         ZMB     40.471           15.4
# 194             Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 1             Low income
# 2    Upper middle income
# 5            High income
# 7            High income
# 10   Upper middle income
# ..                   ...
# ...

# %%
df[(df.BirthRate>30)& (df.InternetUsers>10)]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 2                   Angola         AGO     45.985           19.1
# 63                   Ghana         GHA     33.131           12.3
# 65             Gambia, The         GMB     42.525           14.0
# 67       Equatorial Guinea         GNQ     35.362           16.4
# 91                   Kenya         KEN     35.194           39.0
# 128                Nigeria         NGA     40.045           38.0
# 150                  Sudan         SDN     33.477           22.7
# 151                Senegal         SEN     38.533           13.1
# 158            South Sudan         SSD     37.126           14.1
# 159  Sao Tome and Principe         STP     34.537           23.0
# 164              Swaziland         SWZ     30.093           24.7
# 170             Tajikistan         TJK     30.792           16.0
# 178                 Uganda         UGA     43.474           16.2
# ...

# %%
df[df.IncomeGroup=='Low income']
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 38                    Comoros         COM     34.326           6.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# 64                     Guinea         GIN     37.337           1.60
# 65                Gambia, The         GMB     42.525          14.00
# 66              Guinea-Bissau         GNB     37.503           3.10
# 77                      Haiti         HTI     25.345          10.60
# 93                   Cambodia         KHM     24.462           6.80
# ...

# %%
len(df[df.IncomeGroup=='Low income'])
# Out:
# 30

# %% [markdown]
# #### to get unique categories

# %%
df.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)
