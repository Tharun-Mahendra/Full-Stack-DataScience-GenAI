# %% [markdown]
# # Update Variable

# %%
def update():
    x=10
    print(x)

# %%
update()
# Out:
# 10

# %%
update(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 update(10)
#
# TypeError: update() takes 0 positional arguments but 1 was given

# %%
def update(x):
    x=10
    print(x)

# %%
update(7)
# Out:
# 10

# %%
def update(x):
    return x

# %%
update(10)
# Out:
# 10

# %% [markdown]
# # Arguments
# -     In Python, arguments are values passed to a function when calling it.

# %% [markdown]
# ## 1.Positional Arguments
# -     These are standard arguments that must be provided in the correct order when calling a function.

# %%
def greet(name, age):
    print("Hello",name,"you are",age,"years old.")

greet("Alice", 25)  # Correct usage
greet(25, "Alice")  # Incorrect order
# Out:
# Hello Alice you are 25 years old.
# Hello 25 you are Alice years old.

# %% [markdown]
# ## 2.Default Arguments
# -     These allow you to set default values for parameters, making them optional.

# %%
def greet(name, age=18): 
    print("Hello",name,"you are",age,"years old.")

greet("Bob")  # Uses the default age of 18
greet("Charlie", 22)  # Overrides the default
# Out:
# Hello Bob you are 18 years old.
# Hello Charlie you are 22 years old.

# %% [markdown]
# ## 3.Keyword Arguments
# -     You can explicitly specify argument names, avoiding ordering issues.

# %%
def greet(name, age):
    print(f"Hello {name}, you are {age} years old.")

greet(age=30, name="Dave")  # Correct usage with keyword arguments
# Out:
# Hello Dave, you are 30 years old.
